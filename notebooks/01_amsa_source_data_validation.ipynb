# %% [markdown]
# # AMSA source-data validation
# Run the CLI first, then inspect `data/processed/...` outputs here.

# %%
import pandas as pd
alerts = pd.read_csv('../data/processed/sample/alerts.csv')
alerts.head()
